# %% [markdown]
# SETS (Hash Table)
# They are iterable, mutable and no duplicate elements

# %%
set_var= {"avengers", 100, 12, 12}
set_var.add(11)
print(set_var)
# Out:
# {11, 'avengers', 100, 12}

# %%
#no indexing

# %% [markdown]
# Dictionary
# They are unordered, changeable and indexed

# %%
dic={}
#key and value
my_dict= {"car1":"Audi" , "Car2": "BMW"}
my_dict["car1"]
# Out:
# 'Audi'

# %%
for x in my_dict.values():
    print(x)
# Out:
# Audi
# BMW

# %%
for x in my_dict:
    print(x)
# Out:
# car1
# Car2

# %%
for x in my_dict.items():
    print(x)
# Out:
# ('car1', 'Audi')
# ('Car2', 'BMW')

# %%
my_dict["car4"]= 'i10'
my_dict
# Out:
# {'car1': 'Audi', 'Car2': 'BMW', 'car4': 'i10'}

# %% [markdown]
# Tuples-
# They are not mutable and indexing by index number

# %%
my_tuple= ("krish", "ankur", "John")
my_tuple[0]
# Out:
# 'krish'
