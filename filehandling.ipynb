# %%
#new file created
with open("joke.text", "w") as f:
    f.write("my memory so bad.\n")
    f.write("hey what?")

# %%
with open("joke.text", "r") as f:
    content= f.read()
    print(content)
# Out:
# my memory so bad.
# hey what?

# %%
#use json.dump to add text in file
