# %% [markdown]
# Initial Descriptive Statistical Analysis

# %%
# Mean= Sum of obs/ Total num of obs

#Manually
sum= df['column_name'].sum()
tot= df['column_name'].count() or len( df['column_name'])
mean= sum/tot
print("Mean of column_name is: ",mean)

# %%
#Median
len( df['column_name']) // 2

#Sorts and Creates new indexes from zero
df['column_name'].sort_values(ignore_index= True)[index_num]

# %%
#Mode
df['column_name'].value_counts()

# %%
#Functions
print("Mean of column_name is: ",df['column_name'].mean())
print("Median of column_name is: ",df['column_name'].median())
print("Mode of column_name is: ",df['column_name'].mode())

# %%
#Varience and Standard Deviation
print("Varience of column_name is: ",df['column_name'].var())
print("Standard Deviation of column_name is: ",df['column_name'].std())

# %%
#Standard Deviation is sq root of Varience
import math
std= math.sqrt(df['column_name'].var())
std

# %%
#Range -> max and min

max=df["column_name"].max()
min=df["column_name"].min()

print('The range is between', max-min)

# %%
#Percentiles

per= np.percentile(df['column_name'], percentile)
per

# %%
#Quartiles -> Q1=25 Q2=50 Q3=75

df["column_name"].quantile(0.25)
df["column_name"].quantile(0.55)
df["column_name"].quantile(0.75)

# %%
#Correlation
df.corr()

#Plot
plt.figure(figsize=(15,10)) #Plot size                     
sns.heatmap(df.corr(), annot= True)  #shows value: -ve means -vely correlated and vice versa
